# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.12.5          |   py36h5fab9bb_1         143 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.1.0                |     pyhd3deb0d_0          64 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         240 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.1.0-pyhd3deb0d_0
#
# The following packages will be UPDATED:
#
#   certifi                          2020.12.5-py36h5fab9bb_0 --> 2020.12.5-py36h5fab9bb_1
#
#
#
# Downloading and Extracting Packages
# geopy-2.1.0          | 64 KB     | ##################################### | 100%
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# <h2>Load & Clean Data from list of StartUps</h2>

# %%
#read csv file
df = pd.read_csv("it-startups.csv")

#removing rows with Post Code 'Not assigned'
df.dropna(subset = ["Post Code"], inplace=True)
df

#drop columns with data not required
df.drop(df.columns[[0, 3]], axis = 1, inplace = True)
df.reset_index(drop=True, inplace = True)
df
# Out:
#              Name Post Code                                        Description
# 0            BULB  EC2M 3TQ  The UK’s biggest green supplier, Bulb supplies...
# 1     CITY PANTRY  EC4M 7RF  Believing food is the source of happiness (bec...
# 2         PERKBOX  EC1R 5EJ  Perkbox enriches the employee experience, by p...
# 3       AIRSORTED  EC1M 4NL  Taking the hassle out of hosting, Airsorted is...
# 4            ZOPA   SE1 2QG  Say goodbye to time-consuming middlemen with Z...
# 5      STREETBEES  WC2H 7DQ  Streetbees’ global intelligence platform enabl...
# 6          PAPIER  EC4M 7AN  Papier is kicking it old school with beautiful...
# 7       TRIPTEASE  EC1M 7AD  A company looking to preserve the hotel indust...
# 8      IMPROBABLE  WC2H 7DT  Building, quite literally, whole new worlds us...
# 9     APPEAR HERE  EC1R 5DW  As the leading online marketplace for short-te...
# 10       OAKNORTH   W1F 9QS  Want to work with the UK’s top businesses and ...
# 11         ONFIDO  EC2M 2PA  Concerned about identity fraud? Fear not. Onfi...
# 12          CUVVA  EC1V 1NY  Cuvva is going back to basics with its product...
# 13         MONESE  EC2V 8AU  As our lives become more flexible, so should t...
# 14       BLOW LTD    N8 9EN  Referred to as the ‘Uber for Beauty’, Blow is ...
# 15         THRIVA  EC1N 8UB  Thriva offers a personalised at-home finger-pr...
# 16      KORU KIDS  EC1V 2NX  Koru Kids provides modern childcare solutions ...
# 17   TRANSFERWISE    E1 6JJ  TransferWise offers a faster, more affordable ...
# 18     GOCARDLESS  EC1V 7EN  Looking to take the expense and time out of co...
# 19          IWOCA  EC4R 1AG  Named one of BusinessCloud’s 101 FinTech Disru...
# 20       JUSTPARK   NW1 9PX  JustPark creates pain-free parking for users a...
# 21        TESSIAN  EC2M 2PA  Tessian deploys machine learning to improve em...
# 22           OLIO  SE19 3RW  Tackling waste via the sharing economy, Olio h...
# 23        FLUIDLY    N1 7GU  Solving a real pain point for businesses, Flui...
# 24          CURVE   E14 8PX  On a mission to simplify the way people spend,...
# 25       FLATFAIR  EC2V 6DN  With tenancy deposits in the UK reaching extor...
# 26     RESIDENTLY  EC3M 5JD  Disrupting the archaic rental industry, Reside...
# 27         POLYAI  WC1X 8HN  On the frontier of conversational artificial i...
# 28     WAGESTREAM  WC1V 6PX  Founded as a force for good to reduce financia...
# 29         ATTEST    N1 7GU  By unearthing consumer insights and putting da...
# 30  BUTTERNUT BOX  SW19 5EE  Putting food back into dog food, Butternut Box...
# 31         HUBBLE  EC3M 8AA  One of the UK’s leading PropTech scale-ups, Hu...
# 32     WHAT3WORDS    W2 5EU  By dividing the world into 3m x 3m squares wit...
# 33           CLEO    N4 2BT  Providing a helping hand with money, Cleo help...
# 34     HUCKLETREE  EC2A 1AH  Launched in 2014, Huckletree is on a mission t...
# 35       LENDABLE    E1 6JE  Offering fast loans at fair rates, Lendable ma...
# 36       MONEYBOX   SE1 9PG  Helping a generation save and invest in their ...
# 37        SANCTUS  EC1V 2NX  Sanctus is on a mission to change the percepti...

# %% [markdown]
# <h2>Add missing information to dataset</h2>

# %%
#Get latitude and longitude information for each startup
postcodes = df["Post Code"]
postcodes

lat=[]
long=[]

for p in postcodes:
    url = "http://api.getthedata.com/postcode/"+p
    #print (url)
    
    response = requests.get(url)
    #print (response.text)

    json_data = json.loads(response.text)

    #print(json_data["data"]["latitude"])
    #print(json_data["data"]["longitude"])
    
    lat.append(json_data["data"]["latitude"])
    long.append(json_data["data"]["longitude"])
    

#Add latitude and longitude information to dataframe
df['Latitude']= lat
df['Longitude'] = long

df["Latitude"] = pd.to_numeric(df["Latitude"])
df["Longitude"] = pd.to_numeric(df["Longitude"])

df
# Out:
#              Name Post Code  \
# 0            BULB  EC2M 3TQ
# 1     CITY PANTRY  EC4M 7RF
# 2         PERKBOX  EC1R 5EJ
# 3       AIRSORTED  EC1M 4NL
# 4            ZOPA   SE1 2QG
# 5      STREETBEES  WC2H 7DQ
# 6          PAPIER  EC4M 7AN
# 7       TRIPTEASE  EC1M 7AD
# 8      IMPROBABLE  WC2H 7DT
# 9     APPEAR HERE  EC1R 5DW
# 10       OAKNORTH   W1F 9QS
# 11         ONFIDO  EC2M 2PA
# 12          CUVVA  EC1V 1NY
# 13         MONESE  EC2V 8AU
# 14       BLOW LTD    N8 9EN
# 15         THRIVA  EC1N 8UB
# 16      KORU KIDS  EC1V 2NX
# 17   TRANSFERWISE    E1 6JJ
# 18     GOCARDLESS  EC1V 7EN
# 19          IWOCA  EC4R 1AG
# 20       JUSTPARK   NW1 9PX
# 21        TESSIAN  EC2M 2PA
# 22           OLIO  SE19 3RW
# 23        FLUIDLY    N1 7GU
# 24          CURVE   E14 8PX
# 25       FLATFAIR  EC2V 6DN
# 26     RESIDENTLY  EC3M 5JD
# 27         POLYAI  WC1X 8HN
# 28     WAGESTREAM  WC1V 6PX
# 29         ATTEST    N1 7GU
# 30  BUTTERNUT BOX  SW19 5EE
# 31         HUBBLE  EC3M 8AA
# 32     WHAT3WORDS    W2 5EU
# 33           CLEO    N4 2BT
# 34     HUCKLETREE  EC2A 1AH
# 35       LENDABLE    E1 6JE
# 36       MONEYBOX   SE1 9PG
# 37        SANCTUS  EC1V 2NX
#
#                                           Description   Latitude  Longitude
# 0   The UK’s biggest green supplier, Bulb supplies...  51.518768  -0.080096
# 1   Believing food is the source of happiness (bec...  51.516445  -0.103125
# 2   Perkbox enriches the employee experience, by p...  51.522667  -0.108661
# 3   Taking the hassle out of hosting, Airsorted is...  51.521737  -0.103297
# 4   Say goodbye to time-consuming middlemen with Z...  51.506059  -0.084812
# 5   Streetbees’ global intelligence platform enabl...  51.509080  -0.131128
# 6   Papier is kicking it old school with beautiful...  51.515715  -0.102380
# 7   A company looking to preserve the hotel indust...  51.523126  -0.097949
# 8   Building, quite literally, whole new worlds us...  51.509825  -0.131491
# 9   As the leading online marketplace for short-te...  51.522437  -0.111093
# 10  Want to work with the UK’s top businesses and ...  51.513054  -0.137195
# 11  Concerned about identity fraud? Fear not. Onfi...  51.519645  -0.084083
# 12  Cuvva is going back to basics with its product...  51.532454  -0.105502
# 13  As our lives become more flexible, so should t...  51.513922  -0.092262
# 14  Referred to as the ‘Uber for Beauty’, Blow is ...  51.575345  -0.120994
# 15  Thriva offers a personalised at-home finger-pr...  51.520489  -0.108942
# 16  Koru Kids provides modern childcare solutions ...  51.527304  -0.088894
# 17  TransferWise offers a faster, more affordable ...  51.524074  -0.076689
# 18  Looking to take the expense and time out of co...  51.524419  -0.099539
# 19  Named one of BusinessCloud’s 101 FinTech Disru...  51.510276  -0.093008
# 20  JustPark creates pain-free parking for users a...  51.544306  -0.141284
# 21  Tessian deploys machine learning to improve em...  51.519645  -0.084083
# 22  Tackling waste via the sharing economy, Olio h...  51.417882  -0.081927
# 23  Solving a real pain point for businesses, Flui...  51.530785  -0.093391
# 24  On a mission to simplify the way people spend,...  51.496112  -0.024576
# 25  With tenancy deposits in the UK reaching extor...  51.514177  -0.093577
# 26  Disrupting the archaic rental industry, Reside...  51.512845  -0.078673
# 27  On the frontier of conversational artificial i...  51.518925  -0.111382
# 28  Founded as a force for good to reduce financia...  51.517516  -0.122222
# 29  By unearthing consumer insights and putting da...  51.530785  -0.093391
# 30  Putting food back into dog food, Butternut Box...  51.425463  -0.218651
# 31  One of the UK’s leading PropTech scale-ups, Hu...  51.511030  -0.084255
# 32  By dividing the world into 3m x 3m squares wit...  51.521197  -0.196334
# 33  Providing a helping hand with money, Cleo help...  51.561971  -0.101246
# 34  Launched in 2014, Huckletree is on a mission t...  51.522080  -0.086314
# 35  Offering fast loans at fair rates, Lendable ma...  51.526418  -0.078275
# 36  Helping a generation save and invest in their ...  51.507581  -0.107744
# 37  Sanctus is on a mission to change the percepti...  51.527304  -0.088894

# %%
#Get the latitude and longitude data for London
from geopy.geocoders import Nominatim 
address = 'London, United Kingdom'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinate of London are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinate of London are 51.5073219, -0.1276474.

# %%
import folium

# create map of Toronto using latitude and longitude values
map_london = folium.Map(location=[latitude, longitude], tiles='Stamen Terrain', zoom_start=14)

# add markers to map
for Latitude, Longitude, Name, Description in zip(df['Latitude'], df['Longitude'], df['Name'], df['Description']):
    label = '{}, {}'.format(Name, Description)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [Latitude, Longitude],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h2>Using Foursquare to explore neighbourhoods</h2>

# %%
#Setting the credentials to use Four Square
CLIENT_ID = 'RNJ0DDXZB2L4SWVE4SQB4GDO1CYQKQTIXDK1ACQ2F4W3MQJP' # your Foursquare ID
CLIENT_SECRET = 'XZ0KMUQHZN3YIRY4UL1OU3JFXIP5F1LH2NYG0XKKAHOY0BVA'
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RNJ0DDXZB2L4SWVE4SQB4GDO1CYQKQTIXDK1ACQ2F4W3MQJP
# CLIENT_SECRET:XZ0KMUQHZN3YIRY4UL1OU3JFXIP5F1LH2NYG0XKKAHOY0BVA

# %%
#getting all venues mentioning Primary school within a radius of 500 from each start up
search_query = 'Primary School'
radius = 500

v =[]

columns = ['name', 'location.lat','location.lng']
all_venues = pd.DataFrame(columns=columns)

#getting the latitude and longitude of every start up
lat = df["Latitude"]

for l in lat:
    
    latitude = l
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    results = requests.get(url).json()

    # assign relevant part of JSON to venues
    venues = results['response']['venues']

    # tranform venues into a dataframe
    dataframe = pd.json_normalize(venues)
    df1 = dataframe[['name','location.lat','location.lng']]

    v.append(df1)

all_venues = pd.concat(v)


all_venues

# %%
#reset index
all_venues.reset_index(drop=True, inplace=True)


names = all_venues['name']
names.drop_duplicates(keep = False, inplace = True) 



primary_schools =[]

for n in names:
    if ("Primary School") in n:
        #print (n)
        lat = all_venues.loc[all_venues['name'] == n,'location.lat'].item()
        lng = all_venues.loc[all_venues['name'] == n,'location.lng'].item()
        #print(lat)
        df2 = [n,lat,lng]
        primary_schools.append(df2)
    

columns = ['name', 'location.lat','location.lng']
schools = pd.DataFrame(columns=columns)

schools = pd.DataFrame(primary_schools)
schools.columns = ['name','lat', 'long']

schools



#schools
# Out:
#                                          name        lat      long
# 0                    Coleridge Primary School  51.575719 -0.127154
# 1                    Brecknock Primary School  51.547299 -0.127390
# 2                 Robert Blair Primary School  51.544872 -0.121724
# 3                   Hungerford Primary School  51.548749 -0.126782
# 4                Woodmansterne Primary School  51.418440 -0.135864
# 5                     Millbank Primary School  51.492023 -0.130362
# 6  St John's Upper Holloway CE Primary School  51.562584 -0.132689
# 7                      Yerbury Primary School  51.561164 -0.128212
# 8                     Ashmount Primary School  51.560739 -0.124368
# 9               Upper Holloway Primary School  51.562326 -0.132686

# %%
#drawing map with startups and primary school
import folium

# create map of London using latitude and longitude values
map_london = folium.Map(location=[latitude, longitude], tiles='Stamen Terrain', zoom_start=10)

# add markers to map for startups
for Latitude, Longitude, Name, Description in zip(df['Latitude'], df['Longitude'], df['Name'], df['Description']):
    label = '{}, {}'.format(Name, Description)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [Latitude, Longitude],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
# add markers to map for Primary schools
for Name, Longitude, Latitude, in zip(schools['name'], schools['long'], schools['lat']):
    label = '{}'.format(Name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [Latitude, Longitude],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
